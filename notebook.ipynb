# %%
import pandas as pd

# %%
pop_nl = pd.read_excel('netherlands.xlsx',header=0).transpose()
pop_nl.columns = pop_nl.iloc[1]
pop_nl = pop_nl.reset_index()
pop_nl = pop_nl.drop([0,1,2])

pop_nb = pd.read_excel('noord_brabant.xlsx',header=0).transpose()
pop_nb.columns = pop_nb.iloc[1]
pop_nb = pop_nb.reset_index()
pop_nb = pop_nb.drop([0,1,2])

pop_db = pd.read_excel('noord_brabant.xlsx',header=0).transpose()
pop_db.columns = pop_db.iloc[1]
pop_db = pop_db.reset_index()
pop_db = pop_db.drop([0,1,2])

# %%
pop_nl.to_excel('netherlands.xlsx')

# %%
pop_nb.to_excel('noord_brabant.xlsx')

# %%
pop_db.to_excel('den_bosch.xlsx')

# %%
pop_nl.columns
# Out:
# Index(['index', 'Population at the start of period', 'Children born alive',
#        'Deceased', 'Moved to municipality|Total',
#        'Moved to municipality |Moved from other municipality',
#        'Moved to municipality | Immigration',
#        'Moved from municipality |Total (incl. adm. corrections)',
#        'Moved from municipality |Moved to other municipality',
#        'Moved from municipality |Emigration (incl. adm. corrections) ',
#        'Other corrections', 'Population growth | population growth',
#        'Population growth | population growth, relative',
#        'Population growth | population growth since 1 January',
#        'Population growth | population growth since 1 January, relative',
#        'Population at end of the period'],
#       dtype='object', name='Topic')

# %%
pop_nl[['Population growth | population growth, relative']].plot(title='Netherlands')
# Out:
# <AxesSubplot:title={'center':'Netherlands'}>

# %%
pop_nb[['Moved to municipality|Total','Moved from municipality |Total (incl. adm. corrections)']].plot(title='Noord-Brabant',kind='line')
# Out:
# <AxesSubplot:title={'center':'Noord-Brabant'}>

# %%
pop_db[['Moved to municipality|Total','Moved from municipality |Total (incl. adm. corrections)']].plot(title='Netherlands',)
# Out:
# <AxesSubplot:title={'center':'Netherlands'}>
